# %%
import pandas as pd
pd.options.display.max_rows = 10
pd.options.display.max_columns = 10

# %% [markdown]
# **a. Extraer la información del archivo**

# %%
vacunas = pd.read_csv('/content/country_vaccinations.csv')
vacunas.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    ...  people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0  ...                                  NaN                             NaN
# 1  ...                                  NaN                            34.0
# 2  ...                                  NaN                            34.0
# 3  ...                                  NaN                            34.0
# 4  ...                                  NaN                            34.0
#
#                                             vaccines  \
# ...

# %% [markdown]
# **b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones
# puedes realizar con cada una de ellas, asegurandote que las columnas con fechas sean del
# tipo datetime64.**

# %%
vacunas['date'] = pd.to_datetime(vacunas['date'])
vacunas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %% [markdown]
# **c. Determinar la cantidad de vacunas aplicadas de cada compañía (en base a como lo
# reporta cada país en la columna vaccines)**

# %%
print("La información de la base de datos no corresponde con esta instrucción.")
# Out:
# La información de la base de datos no corresponde con esta instrucción.

# %% [markdown]
# **d. Obtener la cantidad de vacunas aplicadas en todo el mundo**

# %%
vacunas['total_vaccinations'].sum()
# Out:
# 2002854013761.0

# %% [markdown]
# e. **Calcular el promedio de vacunas aplicadas por país**

# %%
vacunas[['country', 'total_vaccinations']].groupby('country').mean()
# Out:
#                    total_vaccinations
# country
# Afghanistan              2.566118e+06
# Albania                  1.191695e+06
# Algeria                  9.956086e+06
# Andorra                  5.827721e+04
# Angola                   6.074066e+06
# ...                               ...
# Wales                    4.132861e+06
# Wallis and Futuna        9.142925e+03
# Yemen                    4.794049e+05
# Zambia                   1.048484e+06
# Zimbabwe                 4.181618e+06
#
# [223 rows x 1 columns]

# %% [markdown]
# **f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo**

# %%
vacunas_enero = vacunas.loc[vacunas['date'] == "2021-01-29", 'daily_vaccinations']
vacunas_enero.sum()
# Out:
# 4884052.0

# %% [markdown]
# **g. Crear un dataframe nuevo denoninado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw**

# %%
vacunas['diferencias'] = vacunas['daily_vaccinations'] - vacunas['daily_vaccinations_raw']
conDiferencias = vacunas[['daily_vaccinations', 'daily_vaccinations_raw', 'diferencias']]
conDiferencias.sample(10)
# Out:
#        daily_vaccinations  daily_vaccinations_raw  diferencias
# 63225              1351.0                     NaN          NaN
# 70906             20466.0                     NaN          NaN
# 66836               204.0                     NaN          NaN
# 21485               608.0                     NaN          NaN
# 56048              4431.0                     NaN          NaN
# 85458              4276.0                     NaN          NaN
# 53654              1614.0                   137.0       1477.0
# 13567            359899.0                393978.0     -34079.0
# 54008                89.0                     NaN          NaN
# 80155               312.0                     NaN          NaN

# %% [markdown]
# **h. Obtener el período de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua**

# %%
vacunas['date'].max() - vacunas['date'].min()
# Out:
# Timedelta('482 days 00:00:00')

# %% [markdown]
# **i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter / )**

# %%
print("La información de la base de datos no corresponde con esta instrucción.")
# Out:
# La información de la base de datos no corresponde con esta instrucción.

# %% [markdown]
# **j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.**

# %%
antes20 = vacunas.loc[vacunas['date'] < "2020-12-20"]
antes20.head()
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  ...  \
# 13403  Canada      CAN 2020-12-14                 5.0                5.0  ...
# 13404  Canada      CAN 2020-12-15               727.0              727.0  ...
# 13405  Canada      CAN 2020-12-16              3025.0             3025.0  ...
# 13406  Canada      CAN 2020-12-17              7279.0             7279.0  ...
# 13407  Canada      CAN 2020-12-18             11296.0            11296.0  ...
#
#        daily_vaccinations_per_million  \
# 13403                             NaN
# 13404                            19.0
# 13405                            40.0
# 13406                            64.0
# 13407                            74.0
#
#                                                 vaccines  \
# 13403  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13404  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13405  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# ...

# %% [markdown]
# **k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.**

# %%
pfizer = vacunas[vacunas['vaccines'].str.contains('Pfizer')]
pfizer
# Out:
#            country  iso_code       date  total_vaccinations  \
# 0      Afghanistan       AFG 2021-02-22                 0.0
# 1      Afghanistan       AFG 2021-02-23                 NaN
# 2      Afghanistan       AFG 2021-02-24                 NaN
# 3      Afghanistan       AFG 2021-02-25                 NaN
# 4      Afghanistan       AFG 2021-02-26                 NaN
# ...            ...       ...        ...                 ...
# 85069        Wales  OWID_WLS 2022-03-24           6921195.0
# 85070        Wales  OWID_WLS 2022-03-25           6923298.0
# 85071        Wales  OWID_WLS 2022-03-26           6923706.0
# 85072        Wales  OWID_WLS 2022-03-27           6925183.0
# 85073        Wales  OWID_WLS 2022-03-28           6927437.0
#
#        people_vaccinated  ...  \
# 0                    0.0  ...
# 1                    NaN  ...
# 2                    NaN  ...
# 3                    NaN  ...
# 4                    NaN  ...
# ...                  ...  ...
# ...

# %% [markdown]
# **l. Almacenar los dataframes generados (conDiferencias,conCantidad,antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter**

# %%
with pd.ExcelWriter("resultados_reto.xlsx") as writer:
  conDiferencias.to_excel(writer, sheet_name="conDiferencias")
  antes20.to_excel(writer, sheet_name="antes20")
  pfizer.to_excel(writer, sheet_name="pfizer")
